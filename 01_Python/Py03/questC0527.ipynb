# %%
def calculator():
    import math as m

    # while True 문을 사용하여 반복해서 계산 가능하게 설계
    while True:
        try:
            # 인수를 받아서
            user_input = input("두 정수와 연산자를 차례로 입력해주세요 (예시: 5 6 /)")
            input_list = user_input.split()

            # 입력된 값이 숫자 2개 연산자 1개가 맞는지 확인
            if len(input_list) != 3:
                print("잘못된 입력입니다. '숫자 숫자 연산자' 형식으로 입력해주세요.")
                continue

            # 정수와 연산자를 각각의 변수에 할당 
            num1, num2, op = input_list


            # 정수 변환 (정수 변환이 안 될 경우 except ValueError로 이동)
            user_num1 = int(num1)
            user_num2 = int(num2)

            # 연산자에 따라서 연산 수행
            if op == '+':
                result = user_num1 + user_num2
            elif op == '-':
                result = user_num1 - user_num2
            elif op == '*':
                result = user_num1 * user_num2
            elif op == '/':
                # 나눈느 수가 0이면 예외 처리한다
                if user_num2 == 0:
                    raise ZeroDivisionError('0으로는 나눌 수 없습니다.')
                else:
                    result = user_num1 / user_num2
            elif op == "**":
                result = m.pow(user_num1, user_num2)
            else:
                print("지원하지 않는 연산자입니다. (+, -, *, /, ** 중 입력)")
                continue

            # 결과 출력
            print(f"결과 :{result}")

            # 계산을 계속 할지 물어보고 0을 누르면 반복문을 빠져나감
            if input("계속 계산하시겠습니까? (yes = 1, no = 0)") == '0':
                print("계산기를 종료합니다.")
                break

        except ValueError:
            print("잘못된 입력입니다. 정수를 입력해주세요.")
        except ZeroDivisionError as e:
            print(e)

calculator()
# Out:
# 두 정수와 연산자를 차례로 입력해주세요 (예시: 5 6 /) 1 3 +
# 결과 :4
# 계속 계산하시겠습니까? (yes = 1, no = 0) 0
# 계산기를 종료합니다.

# %% [markdown]
# ## 회고
#
# ### 처음 문제를 봤을때 모르는 부분이 많아서 어려움을 겪었는데 같이 하는 다겸님의 설명을 들으며 진행하다보니 이해를 할 수 있게되었다 어떤식으로 코드를 짜야되는지 알게 되었고 같이 하는 팀과의 소통이 얼마나 큰 도움이 되는지 깨닫게 되었다
